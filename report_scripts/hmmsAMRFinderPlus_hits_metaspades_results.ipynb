# %%
import pandas as pd
from os import listdir
import numpy as np
from Bio.SeqIO.FastaIO import SimpleFastaParser
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA

# %%
samples = [
    "cc4_1", "cc4_2", "cc4_3",
    "cd4_1", "cd4_2", "cd4_3",
    "mc4_1", "mc4_2", "mc4_3",
    "md4_1", "md4_2", "md4_3",
    "fc4_1", "fc4_2", "fc4_3",
    "fd4_1", "fd4_2", "fd4_3",
]

hmms = {}

for s in samples:
    base = f"../results_metaspades/{s}/hmms_presence_AMRFinderPlus/presence_results.tsv"

    rawdf = pd.read_csv(base, sep="\t")
    
    hmms[s] = rawdf.loc[:, ["name", "match"]].copy()

rawdf
# Out:
#                        name  match sample
# 0      blaB-IND-MUS-NCBIFAM     21  fd4_3
# 1             ANT_6-NCBIFAM      1  fd4_3
# 2    blaOXA-62_like-NCBIFAM      6  fd4_3
# 3            blaVIM-NCBIFAM      7  fd4_3
# 4         BlaA_Yent-NCBIFAM      3  fd4_3
# ..                      ...    ...    ...
# 567  mac_hydro_EstT-NCBIFAM     53  fd4_3
# 568    MecI_of_mecC-NCBIFAM      4  fd4_3
# 569          blaPAD-NCBIFAM      6  fd4_3
# 570  blaDIM_SIM_IMP-NCBIFAM     19  fd4_3
# 571       ampC_Sliq-NCBIFAM     44  fd4_3
#
# [572 rows x 3 columns]

# %%
hmms["cc4_3"]
# Out:
#                        name  match
# 0        linco_LnuA-NCBIFAM      2
# 1      blaB-IND-MUS-NCBIFAM    141
# 2             ANT_6-NCBIFAM      2
# 3    blaOXA-62_like-NCBIFAM     26
# 4            blaVIM-NCBIFAM     43
# ..                      ...    ...
# 660    MecI_of_mecC-NCBIFAM     46
# 661          blaPAD-NCBIFAM     67
# 662           ANT_9-NCBIFAM      9
# 663  blaDIM_SIM_IMP-NCBIFAM     95
# 664       ampC_Sliq-NCBIFAM    499
#
# [665 rows x 2 columns]

# %%
hmms.keys()
# Out:
# dict_keys(['cc4_1', 'cc4_2', 'cc4_3', 'cd4_1', 'cd4_2', 'cd4_3', 'mc4_1', 'mc4_2', 'mc4_3', 'md4_1', 'md4_2', 'md4_3', 'fc4_1', 'fc4_2', 'fc4_3', 'fd4_1', 'fd4_2', 'fd4_3'])

# %%
all_hits = []
for _, i in hmms.items():
    all_hits += list(i.name.unique())
    
unique_all_hit = sorted(set(all_hits))
print(len(unique_all_hit))


m_hits = pd.DataFrame(unique_all_hit, columns=["name"])
m_hits
# Out:
# 690
#                        name
# 0       154989_fosA-NCBIFAM
# 1    156720500_bleO-NCBIFAM
# 2       1567214_ble-NCBIFAM
# 3    16S_A1408_NpmB-NCBIFAM
# 4     16S_rRNA_NpmA-NCBIFAM
# ..                      ...
# 685          vanZ-A-NCBIFAM
# 686          vanZ-F-NCBIFAM
# 687         vanZ-Pt-NCBIFAM
# 688    viomycin_Vph-NCBIFAM
# 689            zbmA-NCBIFAM
#
# [690 rows x 1 columns]

# %%
for s, x in hmms.items():
    x.rename(columns={"match": s}, inplace=True)
    temp = pd.merge(m_hits, x, how="left", on="name")
    m_hits = temp.copy()
    
m_hits
# Out:
#                        name  cc4_1  cc4_2  cc4_3  cd4_1  cd4_2  cd4_3  mc4_1  \
# 0       154989_fosA-NCBIFAM    7.0   12.0   11.0    7.0    4.0    4.0    1.0
# 1    156720500_bleO-NCBIFAM    9.0   13.0   15.0    6.0    5.0    6.0    NaN
# 2       1567214_ble-NCBIFAM    NaN    1.0    2.0    NaN    NaN    1.0    NaN
# 3    16S_A1408_NpmB-NCBIFAM    2.0    3.0    2.0    1.0    NaN    NaN    NaN
# 4     16S_rRNA_NpmA-NCBIFAM    1.0    2.0    2.0    1.0    NaN    NaN    NaN
# ..                      ...    ...    ...    ...    ...    ...    ...    ...
# 685          vanZ-A-NCBIFAM    1.0    3.0    NaN    NaN    NaN    NaN    NaN
# 686          vanZ-F-NCBIFAM    2.0    4.0    1.0    NaN    NaN    1.0    1.0
# 687         vanZ-Pt-NCBIFAM    2.0    2.0    1.0    NaN    NaN    NaN    NaN
# 688    viomycin_Vph-NCBIFAM    NaN    1.0    NaN    NaN    NaN    NaN    NaN
# 689            zbmA-NCBIFAM    4.0    8.0    9.0    2.0    2.0    3.0    NaN
#
#      mc4_2  mc4_3  md4_1  md4_2  md4_3  fc4_1  fc4_2  fc4_3  fd4_1  fd4_2  \
# 0      8.0    9.0    7.0    3.0   10.0    2.0    2.0    5.0    2.0    2.0
# 1      1.0    2.0    5.0    1.0    4.0   11.0   14.0   21.0    3.0    8.0
# 2      NaN    NaN    1.0    1.0    2.0    2.0    2.0    2.0    NaN    3.0
# 3      1.0    NaN    1.0    NaN    1.0    NaN    NaN    NaN    NaN    NaN
# 4      NaN    NaN    NaN    NaN    1.0    NaN    NaN    NaN    NaN    NaN
# ..     ...    ...    ...    ...    ...    ...    ...    ...    ...    ...
# 685    NaN    1.0    NaN    1.0    NaN    3.0    3.0    2.0    NaN    2.0
# 686    NaN    2.0    2.0    1.0    2.0    3.0    3.0    2.0    3.0    3.0
# 687    NaN    NaN    NaN    NaN    NaN    2.0    3.0    2.0    NaN    2.0
# 688    NaN    NaN    NaN    NaN    NaN    1.0    NaN    1.0    NaN    NaN
# 689    NaN    NaN    3.0    1.0    3.0    5.0    7.0    7.0    2.0    7.0
#
#      fd4_3
# 0      NaN
# 1      4.0
# 2      1.0
# 3      NaN
# 4      NaN
# ..     ...
# 685    1.0
# 686    1.0
# 687    1.0
# 688    NaN
# 689    4.0
#
# [690 rows x 19 columns]

# %% [markdown]
# # PCA

# %%
def adapt_df_for_PCA(df, pivot):
    raw_newdf = df.T.reset_index()
    newdf = raw_newdf.replace(np.nan, 0, regex=True)

    new_header = newdf.iloc[0] #grab the first row for the header
    newdf = newdf[1:] #take the data less the header row
    newdf.columns = new_header #set the header row as the df header

    sample_id = {
        "cc4": 0,
        "cd4": 1,
        "mc4": 2,
        "md4": 3,
        "fc4": 4,
        "fd4": 5
    }
#     print(newdf)
    newdf["sample"] = newdf.apply(lambda x: x[pivot].split("_")[0] , axis=1)
    newdf["sample_ids"] = newdf.apply(lambda x: sample_id[x["sample"]], axis=1)
    
    macro_sample_id = {
        "c": 0,
        "m": 1,
        "f": 2,
    }
    
    macro_sample_location = {
        "c": "Suna Canottieri",
        "m": "Teatro Maggiore",
        "f": "Fondo Toce",
    }
    newdf["macro_sample"] = newdf.apply(lambda x: x[pivot][0] , axis=1)
    newdf["macro_sample_ids"] = newdf.apply(lambda x: macro_sample_id[x["macro_sample"]], axis=1)
    newdf["macro_sample_location"] = newdf.apply(lambda x: macro_sample_location[x["macro_sample"]], axis=1)
    newdf["coast_deep_shapes"] = newdf.apply(lambda x: "coast" if x["sample"][1] == "c" else "deep", axis=1)
    
    return newdf

# %%
newdf = adapt_df_for_PCA(m_hits, pivot="name")
newdf
# Out:
# 0    name 154989_fosA-NCBIFAM 156720500_bleO-NCBIFAM 1567214_ble-NCBIFAM  \
# 1   cc4_1                 7.0                    9.0                   0
# 2   cc4_2                12.0                   13.0                 1.0
# 3   cc4_3                11.0                   15.0                 2.0
# 4   cd4_1                 7.0                    6.0                   0
# 5   cd4_2                 4.0                    5.0                   0
# 6   cd4_3                 4.0                    6.0                 1.0
# 7   mc4_1                 1.0                      0                   0
# 8   mc4_2                 8.0                    1.0                   0
# 9   mc4_3                 9.0                    2.0                   0
# 10  md4_1                 7.0                    5.0                 1.0
# 11  md4_2                 3.0                    1.0                 1.0
# 12  md4_3                10.0                    4.0                 2.0
# 13  fc4_1                 2.0                   11.0                 2.0
# 14  fc4_2                 2.0                   14.0                 2.0
# 15  fc4_3                 5.0                   21.0                 2.0
# 16  fd4_1                 2.0                    3.0                   0
# 17  fd4_2                 2.0                    8.0                 3.0
# 18  fd4_3                   0                    4.0                 1.0
#
# 0  16S_A1408_NpmB-NCBIFAM 16S_rRNA_NpmA-NCBIFAM 16S_rRNA_Rmt_B-NCBIFAM  \
# 1                     2.0                   1.0                    1.0
# 2                     3.0                   2.0                      0
# 3                     2.0                   2.0                    2.0
# 4                     1.0                   1.0                      0
# 5                       0                     0                      0
# 6                       0                     0                      0
# 7                       0                     0                      0
# 8                     1.0                     0                      0
# 9                       0                     0                      0
# 10                    1.0                     0                      0
# 11                      0                     0                      0
# 12                    1.0                   1.0                      0
# 13                      0                     0                      0
# 14                      0                     0                      0
# 15                      0                     0                      0
# 16                      0                     0                      0
# 17                      0                     0                      0
# 18                      0                     0                      0
#
# 0  16S_rRNA_Rmt_C-NCBIFAM 16S_rRNA_Rmt_D-NCBIFAM 16S_rRNA_Rmt_E-NCBIFAM  ...  \
# 1                     1.0                    1.0                    1.0  ...
# 2                       0                      0                      0  ...
# 3                     2.0                    2.0                    2.0  ...
# 4                       0                      0                      0  ...
# 5                       0                      0                      0  ...
# 6                       0                      0                      0  ...
# 7                       0                      0                      0  ...
# 8                       0                      0                      0  ...
# 9                       0                      0                      0  ...
# 10                      0                      0                      0  ...
# 11                      0                      0                      0  ...
# 12                      0                      0                      0  ...
# 13                      0                      0                      0  ...
# 14                      0                      0                      0  ...
# 15                      0                    1.0                      0  ...
# 16                      0                      0                      0  ...
# 17                      0                    1.0                      0  ...
# 18                      0                      0                      0  ...
#
# 0  vanZ-F-NCBIFAM vanZ-Pt-NCBIFAM viomycin_Vph-NCBIFAM zbmA-NCBIFAM sample  \
# 1             2.0             2.0                    0          4.0    cc4
# 2             4.0             2.0                  1.0          8.0    cc4
# 3             1.0             1.0                    0          9.0    cc4
# 4               0               0                    0          2.0    cd4
# 5               0               0                    0          2.0    cd4
# 6             1.0               0                    0          3.0    cd4
# 7             1.0               0                    0            0    mc4
# 8               0               0                    0            0    mc4
# 9             2.0               0                    0            0    mc4
# 10            2.0               0                    0          3.0    md4
# 11            1.0               0                    0          1.0    md4
# 12            2.0               0                    0          3.0    md4
# 13            3.0             2.0                  1.0          5.0    fc4
# 14            3.0             3.0                    0          7.0    fc4
# 15            2.0             2.0                  1.0          7.0    fc4
# 16            3.0               0                    0          2.0    fd4
# 17            3.0             2.0                    0          7.0    fd4
# 18            1.0             1.0                    0          4.0    fd4
#
# 0  sample_ids macro_sample macro_sample_ids macro_sample_location  \
# 1           0            c                0       Suna Canottieri
# 2           0            c                0       Suna Canottieri
# 3           0            c                0       Suna Canottieri
# 4           1            c                0       Suna Canottieri
# 5           1            c                0       Suna Canottieri
# 6           1            c                0       Suna Canottieri
# 7           2            m                1       Teatro Maggiore
# 8           2            m                1       Teatro Maggiore
# 9           2            m                1       Teatro Maggiore
# 10          3            m                1       Teatro Maggiore
# 11          3            m                1       Teatro Maggiore
# 12          3            m                1       Teatro Maggiore
# 13          4            f                2            Fondo Toce
# 14          4            f                2            Fondo Toce
# 15          4            f                2            Fondo Toce
# 16          5            f                2            Fondo Toce
# 17          5            f                2            Fondo Toce
# 18          5            f                2            Fondo Toce
#
# 0  coast_deep_shapes
# 1              coast
# 2              coast
# 3              coast
# 4               deep
# 5               deep
# 6               deep
# 7              coast
# 8              coast
# 9              coast
# 10              deep
# 11              deep
# 12              deep
# 13             coast
# 14             coast
# 15             coast
# 16              deep
# 17              deep
# 18              deep
#
# [18 rows x 697 columns]

# %%
newdf.to_csv("hmms_AMRFinderPlus_hit_metaspades_table.tsv", sep="\t", index=False, header=True)

# %%
def PCA_and_plot(df, features):
    pca = PCA()
    components = pca.fit_transform(df[features])
    
    colors_samples_id = df["sample_ids"]
    colors_samples = df["sample"]
    
    Xt = components
    
    colors_samples_id = df["sample_ids"]
    colors_samples = df["sample"]

    plot = plt.scatter(Xt[:,0], Xt[:,1], c=colors_samples_id, cmap="Paired")
    plt.legend(handles=plot.legend_elements()[0], labels=sorted(set(colors_samples)))
    plt.show()
    
def PCA_and_plot_MACROSAMPLE(df, features):
    pca = PCA()
    components = pca.fit_transform(df[features])
    
    colors_samples_id = df["macro_sample_ids"]
    colors_samples = df["macro_sample"]
    
    Xt = components
    
    colors_samples_id = df["macro_sample_ids"]
    colors_samples = df["macro_sample_location"]
    shapes_samples = list(df["coast_deep_shapes"])

#     plot = plt.scatter(Xt[:,0], Xt[:,1], c=colors_samples_id, cmap="Paired", marker=shapes_samples)
    
    plot = sns.scatterplot(x=Xt[:,0], y=Xt[:,1], hue=colors_samples, palette="tab10", style=shapes_samples)
    
#     plt.legend(handles=plot.legend_elements()[0], labels=sorted(set(colors_samples)))
    plt.show()

# %%
features = sorted(m_hits.name)

# %%
features
# Out:
# ['154989_fosA-NCBIFAM',
#  '156720500_bleO-NCBIFAM',
#  '1567214_ble-NCBIFAM',
#  '16S_A1408_NpmB-NCBIFAM',
#  '16S_rRNA_NpmA-NCBIFAM',
#  '16S_rRNA_Rmt_B-NCBIFAM',
#  '16S_rRNA_Rmt_C-NCBIFAM',
#  '16S_rRNA_Rmt_D-NCBIFAM',
#  '16S_rRNA_Rmt_E-NCBIFAM',
#  '16S_rRNA_Rmt_F-NCBIFAM',
#  '16S_rRNA_Rmt_G-NCBIFAM',
#  '16S_rRNA_Rmt_H-NCBIFAM',
#  '16S_rRNA_Rmt_gen-NCBIFAM',
#  '299782349_fosC-NCBIFAM',
#  '299782351_fosA-NCBIFAM',
#  '354827590_fosA-NCBIFAM',
#  '47473_otr-NCBIFAM',
#  '485965_fosC-NCBIFAM',
#  '498180014_fosA-NCBIFAM',
#  'AAC_2p_IIa-NCBIFAM',
#  'AAC_2p_IIb-NCBIFAM',
#  'AAC_2p_Ia-NCBIFAM',
#  'AAC_2p_Ib-NCBIFAM',
#  'AAC_2p_Ic-NCBIFAM',
#  'AAC_2p_Id-NCBIFAM',
#  'AAC_2p_Ie-NCBIFAM',
#  'AAC_3-NCBIFAM',
#  'AAC_3_I-NCBIFAM',
#  'AAC_3_II-NCBIFAM',
#  'AAC_3_IV-NCBIFAM',
#  'AAC_3_VIII-NCBIFAM',
#  'AAC_3_VIa-NCBIFAM',
#  'AAC_3_XI-NCBIFAM',
#  'AAC_6p_A10-NCBIFAM',
#  'AAC_6p_A29-NCBIFAM',
#  'AAC_6p_A30-NCBIFAM',
#  'AAC_6p_A31-NCBIFAM',
#  'AAC_6p_A34-NCBIFAM',
#  'AAC_6p_A37-NCBIFAM',
#  'AAC_6p_A40-NCBIFAM',
#  'AAC_6p_A48-NCBIFAM',
#  'AAC_6p_A49-NCBIFAM',
#  'AAC_6p_Acine-NCBIFAM',
#  'AAC_6p_Entco-NCBIFAM',
#  'AAC_6p_III-NCBIFAM',
#  'AAC_6p_IIc-NCBIFAM',
#  'AAC_6p_Ia_fam-NCBIFAM',
#  'AAC_6p_Iad-NCBIFAM',
#  'AAC_6p_Iak-NCBIFAM',
#  'AAC_6p_Ian-NCBIFAM',
#  'AAC_6p_Ib-NCBIFAM',
#  'AAC_6p_Id-NCBIFAM',
#  'AAC_6p_Ie-NCBIFAM',
#  'AAC_6p_Ie_fam-NCBIFAM',
#  'AAC_6p_If-NCBIFAM',
#  'AAC_6p_Il-NCBIFAM',
#  'AAC_6p_Im-NCBIFAM',
#  'AAC_6p_Ip-NCBIFAM',
#  'AAC_6p_Iz-NCBIFAM',
#  'AAC_6p_Serra-NCBIFAM',
#  'AAC_6p_Steno-NCBIFAM',
#  'AAC_6p_Strep-NCBIFAM',
#  'AAC_6p_Yersi-NCBIFAM',
#  'AAC_6p_set_A-NCBIFAM',
#  'ABCF_CarA-NCBIFAM',
#  'ABCF_Lsa_all-NCBIFAM',
#  'ABCF_Msr_all-NCBIFAM',
#  'ABCF_OptrA-NCBIFAM',
#  'ABCF_Sal-NCBIFAM',
#  'ABCF_Vga_all-NCBIFAM',
#  'ABCF_producer-NCBIFAM',
#  'ANT_2pp_Ia-NCBIFAM',
#  'ANT_3pp_AadA1-NCBIFAM',
#  'ANT_3pp_AadA3-NCBIFAM',
#  'ANT_3pp_I-NCBIFAM',
#  'ANT_3pp_II-NCBIFAM',
#  'ANT_4p_I-NCBIFAM',
#  'ANT_4p_II-NCBIFAM',
#  'ANT_4p_Ia-NCBIFAM',
#  'ANT_4p_Ib-NCBIFAM',
#  'ANT_6-NCBIFAM',
#  'ANT_6_aadK-NCBIFAM',
#  'ANT_6_aadS-NCBIFAM',
#  'ANT_6_str-NCBIFAM',
#  'ANT_9-NCBIFAM',
#  'APH_2pp_IIIa-NCBIFAM',
#  'APH_2pp_IIa-NCBIFAM',
#  'APH_2pp_I_a_f_h-NCBIFAM',
#  'APH_2pp_Ia-NCBIFAM',
#  'APH_2pp_Ie_IVa-NCBIFAM',
#  'APH_2pp_If_Ih-NCBIFAM',
#  'APH_2pp_Ig-NCBIFAM',
#  'APH_2pp_Ii-NCBIFAM',
#  'APH_3p-NCBIFAM',
#  'APH_3p_A16-NCBIFAM',
#  'APH_3p_I-NCBIFAM',
#  'APH_3p_II-NCBIFAM',
#  'APH_3p_IIIa-NCBIFAM',
#  'APH_3p_IVa-NCBIFAM',
#  'APH_3p_V-NCBIFAM',
#  'APH_3p_VI-NCBIFAM',
#  'APH_3p_VIII-NCBIFAM',
#  'APH_3p_VIIa-NCBIFAM',
#  'APH_3p_XV-NCBIFAM',
#  'APH_3pp-NCBIFAM',
#  'APH_3pp_Ia-NCBIFAM',
#  'APH_3pp_Ib-NCBIFAM',
#  'APH_4_Ia-NCBIFAM',
#  'APH_6-NCBIFAM',
#  'APH_6_Ic-NCBIFAM',
#  'APH_6_Ic_gen-NCBIFAM',
#  'APH_6_Steno-NCBIFAM',
#  'APH_7pp_Ia-NCBIFAM',
#  'APH_9_Ia-NCBIFAM',
#  'APH_9_Ib-NCBIFAM',
#  'B1_blaCHM-NCBIFAM',
#  'B3_blaSPR-NCBIFAM',
#  'BlaA_Yent-NCBIFAM',
#  'BlaEC-NCBIFAM',
#  'BlaI_of_MRSA-NCBIFAM',
#  'BlaMIR-NCBIFAM',
#  'BlmB-NCBIFAM',
#  'CARB-NCBIFAM',
#  'CAR_gen_B3-NCBIFAM',
#  'CHL_hydrolase-NCBIFAM',
#  'CMY2-MIR-ACT-EC-NCBIFAM',
#  'CMY2-NCBIFAM',
#  'CfrAB-NCBIFAM',
#  'D_ala_D_lac-NCBIFAM',
#  'D_ala_D_lac_Ao2-NCBIFAM',
#  'D_ala_D_lac_Sc-NCBIFAM',
#  'D_ala_D_lac_VanA-NCBIFAM',
#  'D_ala_D_lac_VanB-NCBIFAM',
#  'D_ala_D_lac_VanD-NCBIFAM',
#  'D_ala_D_lac_VanF-NCBIFAM',
#  'D_ala_D_lac_VanI-NCBIFAM',
#  'D_ala_D_lac_VanM-NCBIFAM',
#  'D_ala_D_lac_VanO-NCBIFAM',
#  'D_ala_D_ser-NCBIFAM',
#  'D_ala_D_ser_VanC-NCBIFAM',
#  'D_ala_D_ser_VanE-NCBIFAM',
#  'D_ala_D_ser_VanG-NCBIFAM',
#  'D_ala_D_ser_VanL-NCBIFAM',
#  'D_ala_D_ser_VanN-NCBIFAM',
#  'EntFM_CwpFM-NCBIFAM',
#  'EreA-NCBIFAM',
#  'EreB-NCBIFAM',
#  'EreD-NCBIFAM',
#  'Erm23S_rRNA_broad-NCBIFAM',
#  'Erm32-NCBIFAM',
#  'Erm37-NCBIFAM',
#  'Erm42-NCBIFAM',
#  'Erm43-NCBIFAM',
#  'Erm45-NCBIFAM',
#  'Erm46-NCBIFAM',
#  'Erm55-NCBIFAM',
#  'ErmO-NCBIFAM',
#  'ErmS-NCBIFAM',
#  'ErmV-NCBIFAM',
#  'FOX-MOX-NCBIFAM',
#  'FexA-NCBIFAM',
#  'FexB-NCBIFAM',
#  'FloR-NCBIFAM',
#  'FosA-NCBIFAM',
#  'FosF-NCBIFAM',
#  'FosG-NCBIFAM',
#  'FosK-NCBIFAM',
#  'FosLL-NCBIFAM',
#  'FosU-NCBIFAM',
#  'FosX-NCBIFAM',
#  'Fos_BSH-NCBIFAM',
#  'Fos_BSH_Bcer-NCBIFAM',
#  'Fos_BSH_FosY-NCBIFAM',
#  'Fos_BSH_Saur-NCBIFAM',
#  'Fos_BSH_Sepi-NCBIFAM',
#  'Fos_GSH-NCBIFAM',
#  'HARLDQ_not_B3-NCBIFAM',
#  'HK_VanS_ACDEFG-NCBIFAM',
#  'HK_VanS_B-NCBIFAM',
#  'HK_VanS_O-NCBIFAM',
#  'LEN-NCBIFAM',
#  'MATE_multi_MepA-NCBIFAM',
#  'MATE_multi_NorM-NCBIFAM',
#  'MECA1_pure-NCBIFAM',
#  'MECA2_pure-NCBIFAM',
#  'MECA_PBP2A-NCBIFAM',
#  'MECA_pure-NCBIFAM',
#  'MECB_PBP-NCBIFAM',
#  'MECC_PBP-NCBIFAM',
#  'MECD_PBP-NCBIFAM',
#  'MFS_efflux_PexA-NCBIFAM',
#  'MFS_efflux_tcmA-NCBIFAM',
#  'MOX_CMY1_fam-NCBIFAM',
#  'MPH_3-NCBIFAM',
#  'MTB_classA_BlaC-NCBIFAM',
#  'MecI_of_mecA-NCBIFAM',
#  'MecI_of_mecC-NCBIFAM',
#  'MerA-TIGRFAMs',
#  'MerP-TIGRFAMs',
#  'MexE-Resfams',
#  'MsrSA-NCBIFAM',
#  'MupA-NCBIFAM',
#  'MupB-NCBIFAM',
#  'NimABCDEF-NCBIFAM',
#  'NimIJ-NCBIFAM',
#  'NshR_TsnR-NCBIFAM',
#  'OKP-NCBIFAM',
#  'OqxA_adapt_sub-NCBIFAM',
#  'PRK10026.1-PRK',
#  'PRK13747.1-PRK',
#  'PRK13752.1-PRK',
#  'PSE-NCBIFAM',
#  'QacCGHJ-NCBIFAM',
#  'RND_adapt_MexA-NCBIFAM',
#  'RND_perm_OqxB-NCBIFAM',
#  'RPH_KJ151292.1-NCBIFAM',
#  'RTG-NCBIFAM',
#  'SHV-NCBIFAM',
#  'SHV_LEN_OKP-NCBIFAM',
#  'SMB1_fam-NCBIFAM',
#  'SMR_efflux_EmrE-NCBIFAM',
#  'SMR_efflux_smr-NCBIFAM',
#  'SMR_qac_E-NCBIFAM',
#  'SMR_qac_FL-NCBIFAM',
#  'SMR_qac_G2-NCBIFAM',
#  'SMR_qac_K-NCBIFAM',
#  'SMR_qac_bcrB-NCBIFAM',
#  'SMR_qac_bcrC-NCBIFAM',
#  'SMR_qac_int-NCBIFAM',
#  'SMR_qac_pB8-NCBIFAM',
#  'SubclassA2-NCBIFAM',
#  'Sul1-NCBIFAM',
#  'Sul2-NCBIFAM',
#  'Sul3-NCBIFAM',
#  'Sul4-NCBIFAM',
#  'TlmB-NCBIFAM',
#  'VanC1_ser_lig-NCBIFAM',
#  'VarG_fam_MBL-NCBIFAM',
#  'Vat_ABCDEFH-NCBIFAM',
#  'YadA_autotrans-NCBIFAM',
#  'acid_shock_Asr-NCBIFAM',
#  'amicyc_ac_ApmA-NCBIFAM',
#  'ampC_Ecan-NCBIFAM',
#  'ampC_Kaer-NCBIFAM',
#  'ampC_Sliq-NCBIFAM',
#  'arsB_Sta_pI258-NCBIFAM',
#  'bla-A_Chryseo-NCBIFAM',
#  'bla-B1-FLAV-NCBIFAM',
#  'bla1-NCBIFAM',
#  'blaAAK-NCBIFAM',
#  'blaACC-NCBIFAM',
#  'blaACI-NCBIFAM',
#  'blaACT-NCBIFAM',
#  'blaADC-NCBIFAM',
#  'blaAFM-NCBIFAM',
#  'blaAIM-NCBIFAM',
#  'blaALI-NCBIFAM',
#  'blaAMZ-NCBIFAM',
#  'blaAQU-NCBIFAM',
#  'blaARL-NCBIFAM',
#  'blaAXC-NCBIFAM',
#  'blaB-IND-MUS-NCBIFAM',
#  'blaB-NCBIFAM',
#  'blaBBI-NCBIFAM',
#  'blaBCL-NCBIFAM',
#  'blaBEL-NCBIFAM',
#  'blaBES-NCBIFAM',
#  'blaBIC-NCBIFAM',
#  'blaBIM-NCBIFAM',
#  'blaBJP-NCBIFAM',
#  'blaBKC-NCBIFAM',
#  'blaBKC_GPC-NCBIFAM',
#  'blaBOR-NCBIFAM',
#  'blaBPU-NCBIFAM',
#  'blaBUT-NCBIFAM',
#  'blaCAE-NCBIFAM',
#  'blaCAM-NCBIFAM',
#  'blaCAU-NCBIFAM',
#  'blaCBP-NCBIFAM',
#  'blaCDD-NCBIFAM',
#  'blaCIA-NCBIFAM',
#  'blaCMA-NCBIFAM',
#  'blaCME-NCBIFAM',
#  'blaCMH-NCBIFAM',
#  'blaCPS-NCBIFAM',
#  'blaCRH-NCBIFAM',
#  'blaCRP-NCBIFAM',
#  'blaCSA-NCBIFAM',
#  'blaCTX-M-NCBIFAM',
#  'blaCVI-NCBIFAM',
#  'blaCcrA-NCBIFAM',
#  'blaDHA-NCBIFAM',
#  'blaDIM-NCBIFAM',
#  'blaDIM_SIM_IMP-NCBIFAM',
#  'blaEAM-NCBIFAM',
#  'blaEBR-NCBIFAM',
#  'blaECM-NCBIFAM',
#  'blaEFM-NCBIFAM',
#  'blaESP-1_fam-NCBIFAM',
#  'blaFEZ-NCBIFAM',
#  'blaFIM-NCBIFAM',
#  'blaFONA-NCBIFAM',
#  'blaFOX-NCBIFAM',
#  'blaFRI-NCBIFAM',
#  'blaFTU-NCBIFAM',
#  'blaGES-NCBIFAM',
#  'blaGIL-NCBIFAM',
#  'blaGIM-NCBIFAM',
#  'blaGMA-NCBIFAM',
#  'blaGMB-NCBIFAM',
#  'blaGOB-NCBIFAM',
#  'blaHBL-NCBIFAM',
#  'blaHER-NCBIFAM',
#  'blaHMB-NCBIFAM',
#  'blaIDC-NCBIFAM',
#  'blaIMI-NCBIFAM',
#  'blaIMP-NCBIFAM',
#  'blaIND-NCBIFAM',
#  'blaKBL-NCBIFAM',
#  'blaKHM-HMB-NCBIFAM',
#  'blaKHM-NCBIFAM',
#  'blaKLUC-NCBIFAM',
#  'blaKPC-NCBIFAM',
#  'blaL-NCBIFAM',
#  'blaL1-NCBIFAM',
#  'blaLAP-NCBIFAM',
#  'blaLAQ-NCBIFAM',
#  'blaLHK-NCBIFAM',
#  'blaLUT-NCBIFAM',
#  'blaMAB-NCBIFAM',
#  'blaMCA-NCBIFAM',
#  'blaMSI-1_fam-NCBIFAM',
#  'blaMUS-NCBIFAM',
#  'blaNDM-NCBIFAM',
#  'blaOCH-NCBIFAM',
#  'blaORN-NCBIFAM',
#  'blaOXA-1036_like-NCBIFAM',
#  'blaOXA-1043_like-NCBIFAM',
#  'blaOXA-1089_like-NCBIFAM',
#  'blaOXA-1091_like-NCBIFAM',
#  'blaOXA-10_like-NCBIFAM',
#  'blaOXA-114_like-NCBIFAM',
#  'blaOXA-12_like-NCBIFAM',
#  'blaOXA-134_like-NCBIFAM',
#  'blaOXA-143_like-NCBIFAM',
#  'blaOXA-184_like-NCBIFAM',
#  'blaOXA-198_like-NCBIFAM',
#  'blaOXA-1_like-NCBIFAM',
#  'blaOXA-211_like-NCBIFAM',
#  'blaOXA-213_like-NCBIFAM',
#  'blaOXA-214_like-NCBIFAM',
#  'blaOXA-229_like-NCBIFAM',
#  'blaOXA-22_like-NCBIFAM',
#  'blaOXA-23_like-NCBIFAM',
#  'blaOXA-24_like-NCBIFAM',
#  'blaOXA-266_like-NCBIFAM',
#  'blaOXA-274_like-NCBIFAM',
#  'blaOXA-286_like-NCBIFAM',
#  'blaOXA-294_like-NCBIFAM',
#  'blaOXA-2_like-NCBIFAM',
#  'blaOXA-364_like-NCBIFAM',
#  'blaOXA-372_like-NCBIFAM',
#  'blaOXA-427_like-NCBIFAM',
#  'blaOXA-42_like-NCBIFAM',
#  'blaOXA-46_like-NCBIFAM',
#  'blaOXA-48_like-NCBIFAM',
#  'blaOXA-493_like-NCBIFAM',
#  'blaOXA-50_like-NCBIFAM',
#  'blaOXA-51_like-NCBIFAM',
#  'blaOXA-548_like-NCBIFAM',
#  'blaOXA-55_like-NCBIFAM',
#  'blaOXA-576_like-NCBIFAM',
#  'blaOXA-58_like-NCBIFAM',
#  'blaOXA-5_like-NCBIFAM',
#  'blaOXA-60_like-NCBIFAM',
#  'blaOXA-61_like-NCBIFAM',
#  'blaOXA-62_like-NCBIFAM',
#  'blaOXA-63_like-NCBIFAM',
#  'blaOXA-679_like-NCBIFAM',
#  'blaOXA-727_like-NCBIFAM',
#  'blaOXA-732_like-NCBIFAM',
#  'blaOXA-837_like-NCBIFAM',
#  'blaOXA-85_like-NCBIFAM',
#  'blaOXA-919_like-NCBIFAM',
#  'blaOXA-9_like-NCBIFAM',
#  'blaOXA-VL06-NCBIFAM',
#  'blaOXA_Campylobacter-NCBIFAM',
#  'blaOXY-NCBIFAM',
#  'blaP-NCBIFAM',
#  'blaPAC-NCBIFAM',
#  'blaPAD-NCBIFAM',
#  'blaPAM-NCBIFAM',
#  'blaPAU-NCBIFAM',
#  'blaPDC-NCBIFAM',
#  'blaPDC_var-NCBIFAM',
#  'blaPEDO-1_fam-NCBIFAM',
#  'blaPEDO-2_fam-NCBIFAM',
#  'blaPEDO-3_fam-NCBIFAM',
#  'blaPEN-Bcc-NCBIFAM',
#  'blaPEN-Bpc-NCBIFAM',
#  'blaPER-NCBIFAM',
#  'blaPFM-NCBIFAM',
#  'blaPJM-NCBIFAM',
#  'blaPLA-NCBIFAM',
#  'blaPLA_ORN_TER-NCBIFAM',
#  'blaPME-NCBIFAM',
#  'blaPOM-NCBIFAM',
#  'blaPRC-NCBIFAM',
#  'blaPST-NCBIFAM',
#  'blaPSV-NCBIFAM',
#  'blaPSZ-NCBIFAM',
#  'blaPenA-NCBIFAM',
#  'blaPenB-NCBIFAM',
#  'blaPenN-NCBIFAM',
#  'blaR1_generic-NCBIFAM',
#  'blaRAA-NCBIFAM',
#  'blaRAD-NCBIFAM',
#  'blaRAHN-NCBIFAM',
#  'blaRASA-NCBIFAM',
#  'blaRATA-NCBIFAM',
#  'blaRCP-NCBIFAM',
#  'blaRHO-NCBIFAM',
#  'blaROB-NCBIFAM',
#  'blaRUB-NCBIFAM',
#  'blaSCO-NCBIFAM',
#  'blaSED-NCBIFAM',
#  'blaSFC-NCBIFAM',
#  'blaSFDC-NCBIFAM',
#  'blaSFH-NCBIFAM',
#  'blaSFH_gen-NCBIFAM',
#  'blaSGM-NCBIFAM',
#  'blaSIM-NCBIFAM',
#  'blaSME-NCBIFAM',
#  'blaSPG-1_fam-NCBIFAM',
#  'blaSPM-NCBIFAM',
#  'blaSRT-NCBIFAM',
#  'blaTEM-NCBIFAM',
#  'blaTER-NCBIFAM',
#  'blaTHIN-NCBIFAM',
#  'blaTLA-NCBIFAM',
#  'blaTMB-NCBIFAM',
#  'blaTTU-NCBIFAM',
#  'blaTUS-NCBIFAM',
#  'blaVCC-NCBIFAM',
#  'blaVEB-NCBIFAM',
#  'blaVIM-NCBIFAM',
#  'blaVMB-NCBIFAM',
#  'blaWUS-NCBIFAM',
#  'blaYEM-NCBIFAM',
#  'blaYRC-NCBIFAM',
#  'blaZ-NCBIFAM',
#  'blaZ_gen-NCBIFAM',
#  'blaZ_mecC_type-NCBIFAM',
#  'bla_B1_long-NCBIFAM',
#  'bla_B2_CphA-NCBIFAM',
#  'bla_Bc_2-NCBIFAM',
#  'bla_Bcer_III-NCBIFAM',
#  'bla_CblA-NCBIFAM',
#  'bla_CepA-NCBIFAM',
#  'bla_CfxA-NCBIFAM',
#  'bla_Exo-NCBIFAM',
#  'bla_class_A-NCBIFAM',
#  'bla_class_B_core-NCBIFAM',
#  'bla_class_C-NCBIFAM',
#  'bla_class_D_alt-NCBIFAM',
#  'bla_class_D_main-NCBIFAM',
#  'bla_subclass_B1-NCBIFAM',
#  'bla_subclass_B2-NCBIFAM',
#  'bla_subclass_B3-NCBIFAM',
#  'bla_xUS-NCBIFAM',
#  'ble_BLMA_gen-NCBIFAM',
#  'ble_BLMT-NCBIFAM',
#  'ble_MBL-NCBIFAM',
#  'ble_Sh-NCBIFAM',
#  'capreo_Cph-NCBIFAM',
#  'carbeni_gen-NCBIFAM',
#  'chaper_CopP-NCBIFAM',
#  'chaperon_ArsD-NCBIFAM',
#  'chloram_CatA-NCBIFAM',
#  'chloram_CatB-NCBIFAM',
#  'chrB-NCBIFAM',
#  'classA_carba-NCBIFAM',
#  'classA_firm-NCBIFAM',
#  'cmlA_floR-NCBIFAM',
#  'cmlB1_MFS-NCBIFAM',
#  'cml_V_MFS-NCBIFAM',
#  'cmx_cmrA-NCBIFAM',
#  'coreg_MerD-NCBIFAM',
#  'dipept_VanX-NCBIFAM',
#  'efflux_CmlA-NCBIFAM',
#  'efflux_Cmx-NCBIFAM',
#  'efflux_OM_AdeC-NCBIFAM',
#  'erm_38_23S_MT-NCBIFAM',
#  'erm_A_23S_MT-NCBIFAM',
#  'erm_B_23S_MT-NCBIFAM',
#  'erm_C_23S_MT-NCBIFAM',
#  'erm_F_23S_MT-NCBIFAM',
#  'erm_SHROVE-NCBIFAM',
#  'fomA_AB016934.1.gene6-NCBIFAM',
#  'fos-Crono-NCBIFAM',
#  'fosA5_fam-NCBIFAM',
#  'fosA7-NCBIFAM',
#  'fosA8-NCBIFAM',
#  'fosBx1_fam-NCBIFAM',
#  'fosM_gen-NCBIFAM',
#  'fosX-Cc-NCBIFAM',
#  'fusid_est_FusH-NCBIFAM',
#  'garosamine_AAA-NCBIFAM',
#  'glycotrans_Rgt-NCBIFAM',
#  'heat_AAA_ClpK-NCBIFAM',
#  'intimin_all-NCBIFAM',
#  'intimin_alpha-NCBIFAM',
#  'inverse_SinH-NCBIFAM',
#  'linco_LnuA-NCBIFAM',
#  'linco_LnuAN2-NCBIFAM',
#  'linco_LnuC-NCBIFAM',
#  'linco_LnuD-NCBIFAM',
#  'linco_LnuE-NCBIFAM',
#  'linco_LnuF-NCBIFAM',
#  'linco_LnuP-NCBIFAM',
#  'lyase_MerB-NCBIFAM',
#  'mac_hydro_EstT-NCBIFAM',
#  'macro_glyco_Mgt-NCBIFAM',
#  'macrolide_MefA-NCBIFAM',
#  'macrolide_MefB-NCBIFAM',
#  'macrolide_MefC-NCBIFAM',
#  'macrolide_MefEN2-NCBIFAM',
#  'macrolide_MphA-NCBIFAM',
#  'macrolide_MphB-NCBIFAM',
#  'macrolide_MphC-NCBIFAM',
#  'macrolide_MphE-NCBIFAM',
#  'macrolide_MphF-NCBIFAM',
#  'macrolide_MphL-NCBIFAM',
#  'macrolide_MphM-NCBIFAM',
#  'merT_RC607-NCBIFAM',
#  'metallo_SslE-NCBIFAM',
#  'motor_HelR-NCBIFAM',
#  'myrA-NCBIFAM',
#  'nosihep_NshR-NCBIFAM',
#  'penta_rpt_QnrA-NCBIFAM',
#  'penta_rpt_QnrAS-NCBIFAM',
#  'penta_rpt_QnrB-NCBIFAM',
#  'penta_rpt_QnrC-NCBIFAM',
#  'penta_rpt_QnrD-NCBIFAM',
#  'penta_rpt_QnrE-NCBIFAM',
#  'penta_rpt_QnrS-NCBIFAM',
#  'penta_rpt_QnrVC-NCBIFAM',
#  'phenyl_MerG-NCBIFAM',
#  'phos_trans_CPT-NCBIFAM',
#  'poly_MCR3_broad-NCBIFAM',
#  'polymyxin_MCR1-NCBIFAM',
#  'polymyxin_MCR10-NCBIFAM',
#  'polymyxin_MCR2-NCBIFAM',
#  'polymyxin_MCR3-NCBIFAM',
#  'polymyxin_MCR4-NCBIFAM',
#  'polymyxin_MCR5-NCBIFAM',
#  'polymyxin_MCR6-NCBIFAM',
#  'polymyxin_MCR7-NCBIFAM',
#  'polymyxin_MCR8-NCBIFAM',
#  'polymyxin_MCR9-NCBIFAM',
#  'qac_MFS_AB-NCBIFAM',
#  'qac_SMR_C-NCBIFAM',
#  'qac_SMR_G-NCBIFAM',
#  'qac_SMR_H-NCBIFAM',
#  'qac_SMR_J-NCBIFAM',
#  'qepA-NCBIFAM',
#  'rRNA_meth_EmtA-NCBIFAM',
#  'resist_ArsN1a-NCBIFAM',
#  'resist_ArsN1b-NCBIFAM',
#  'resist_ArsN2-NCBIFAM',
#  'ribo_prot_ABC_F-NCBIFAM',
#  'rif_mono_Iri-NCBIFAM',
#  'rif_monoox-NCBIFAM',
#  'rifampin_ARR-NCBIFAM',
#  'rifampin_ARR_Ms-NCBIFAM',
#  'rifampin_ARR_Sa-NCBIFAM',
#  'sat2-NCBIFAM',
#  'sat3-NCBIFAM',
#  'sat4-NCBIFAM',
#  'self_FomB_kinase-NCBIFAM',
#  'self_GT_OleI-NCBIFAM',
#  'self_KamB-NCBIFAM',
#  'sensor_BlaR1-NCBIFAM',
#  'sensor_MecR1-NCBIFAM',
#  'stat-NCBIFAM',
#  'stregra_B_VgbA-NCBIFAM',
#  'stregra_B_VgbB-NCBIFAM',
#  'stregram_VatA-NCBIFAM',
#  'stregram_VatC-NCBIFAM',
#  'stregram_VatD-NCBIFAM',
#  'stregram_VatE-NCBIFAM',
#  'stregram_VatF-NCBIFAM',
#  'stregram_VatH-NCBIFAM',
#  'stregram_VatI-NCBIFAM',
#  'tet_ABC_46_A-NCBIFAM',
#  'tet_ABC_46_B-NCBIFAM',
#  'tet_ABC_AB_A-NCBIFAM',
#  'tet_ABC_AB_B-NCBIFAM',
#  'tet_MFS_38-NCBIFAM',
#  'tet_MFS_40-NCBIFAM',
#  'tet_MFS_42-NCBIFAM',
#  'tet_MFS_43-NCBIFAM',
#  'tet_MFS_45-NCBIFAM',
#  'tet_MFS_A-NCBIFAM',
#  'tet_MFS_A_B_C_D-NCBIFAM',
#  'tet_MFS_B-NCBIFAM',
#  'tet_MFS_C-NCBIFAM',
#  'tet_MFS_D-NCBIFAM',
#  'tet_MFS_E-NCBIFAM',
#  'tet_MFS_G-NCBIFAM',
#  'tet_MFS_H-NCBIFAM',
#  'tet_MFS_H_J-NCBIFAM',
#  'tet_MFS_J-NCBIFAM',
#  'tet_MFS_K-NCBIFAM',
#  'tet_MFS_L-NCBIFAM',
#  'tet_MFS_L_K_45-NCBIFAM',
#  'tet_MFS_OtrB-NCBIFAM',
#  'tet_MFS_P_a-NCBIFAM',
#  'tet_MFS_Tcr3-NCBIFAM',
#  'tet_MFS_V-NCBIFAM',
#  'tet_MFS_Y-NCBIFAM',
#  'tet_NaH_anti_35-NCBIFAM',
#  'tet_destruct-NCBIFAM',
#  'tet_monoox_X-NCBIFAM',
#  'tet_protect-NCBIFAM',
#  'tet_protect_M-NCBIFAM',
#  'tet_protect_M_W-NCBIFAM',
#  'tet_protect_Q-NCBIFAM',
#  'tet_prtrans_34-NCBIFAM',
#  'tet_redox_37-NCBIFAM',
#  'trans_MerF-NCBIFAM',
#  'trans_reg_VanU-NCBIFAM',
#  'transport_merC-NCBIFAM',
#  'trim_DfrA10-NCBIFAM',
#  'trim_DfrA12-NCBIFAM',
#  'trim_DfrA12_A21-NCBIFAM',
#  'trim_DfrA18-NCBIFAM',
#  'trim_DfrA19-NCBIFAM',
#  'trim_DfrA1_like-NCBIFAM',
#  'trim_DfrA1_rpt-NCBIFAM',
#  'trim_DfrA20-NCBIFAM',
#  'trim_DfrA23-NCBIFAM',
#  'trim_DfrA24-NCBIFAM',
#  'trim_DfrA26-NCBIFAM',
#  'trim_DfrA3-NCBIFAM',
#  'trim_DfrA35-NCBIFAM',
#  'trim_DfrA36-NCBIFAM',
#  'trim_DfrA3b-NCBIFAM',
#  'trim_DfrA8-NCBIFAM',
#  'trim_DfrA9-NCBIFAM',
#  'trim_DfrB-NCBIFAM',
#  'trim_DfrD-NCBIFAM',
#  'trim_DfrDGK-NCBIFAM',
#  'trim_DfrE-NCBIFAM',
#  'trim_DfrF-NCBIFAM',
#  'trim_DfrG-NCBIFAM',
#  'trim_DfrI-NCBIFAM',
#  'trim_DfrL-NCBIFAM',
#  'vanH-Ac1-NCBIFAM',
#  'vanH-Amyco-NCBIFAM',
#  'vanH-D-NCBIFAM',
#  'vanH-Sc-NCBIFAM',
#  'vanH_Agroup-NCBIFAM',
#  'vanH_gen-NCBIFAM',
#  'vanJ-NCBIFAM',
#  'vanR-A-NCBIFAM',
#  'vanR-B-NCBIFAM',
#  'vanR-C-NCBIFAM',
#  'vanR-D-NCBIFAM',
#  'vanR-O-NCBIFAM',
#  'vanR_ACDEGLN-NCBIFAM',
#  'vanR_FM-NCBIFAM',
#  'vanT-CELN-NCBIFAM',
#  'vanT-G-Cterm-NCBIFAM',
#  'vanT-L-cat-NCBIFAM',
#  'vanT-L-mem-NCBIFAM',
#  'vanW-B-NCBIFAM',
#  'vanW-G-NCBIFAM',
#  'vanW-gen-NCBIFAM',
#  'vanXY-NCBIFAM',
#  'vanXY_G-NCBIFAM',
#  'vanY_AFMPt-NCBIFAM',
#  'vanY_BG-NCBIFAM',
#  'vanY_far-NCBIFAM',
#  'vanY_of_D-NCBIFAM',
#  'vanZ-A-NCBIFAM',
#  'vanZ-F-NCBIFAM',
#  'vanZ-Pt-NCBIFAM',
#  'viomycin_Vph-NCBIFAM',
#  'zbmA-NCBIFAM']

# %%
PCA_and_plot(newdf, features)

# %%
PCA_and_plot_MACROSAMPLE(newdf, features)

# %% [markdown]
# # NMDS

# %%
from sklearn.manifold import MDS
from matplotlib import pyplot as plt
import sklearn.datasets as dt
import seaborn as sns         
import numpy as np
from sklearn.metrics.pairwise import manhattan_distances, euclidean_distances
from matplotlib.offsetbox import OffsetImage, AnnotationBbox

# %%
X = newdf[features]

# mds = MDS(random_state=0)
# X_transform = mds.fit_transform(X)

dist_manhattan = manhattan_distances(X)
nmds = MDS(dissimilarity='precomputed', random_state=0, metric=False)

# Get the embeddings
X_transform_L1 = nmds.fit_transform(dist_manhattan)

nmds_Xt = X_transform_L1
# Out:
# /home/davide/mambaforge/envs/microbial_res/lib/python3.8/site-packages/sklearn/manifold/_mds.py:298: FutureWarning: The default value of `normalized_stress` will change to `'auto'` in version 1.4. To suppress this warning, manually set the value of `normalized_stress`.
#   warnings.warn(

# %%
nmds.stress_
# Out:
# 0.23008385719265412

# %%
colors_samples_id = newdf["sample_ids"]
colors_samples = newdf["sample"]

plot = plt.scatter(nmds_Xt[:,0], nmds_Xt[:,1], c=colors_samples_id, cmap="Paired")
plt.legend(handles=plot.legend_elements()[0], labels=sorted(set(colors_samples)))
plt.show()

# %%
colors_samples_id = newdf["macro_sample_ids"]
colors_samples = newdf["macro_sample_location"]
shapes_samples = newdf["coast_deep_shapes"]

# plot = plt.scatter(nmds_Xt[:,0], nmds_Xt[:,1], c=colors_samples_id, cmap="Paired")
# plt.legend(handles=plot.legend_elements()[0], labels=sorted(set(colors_samples)))

plot = sns.scatterplot(x=nmds_Xt[:,0], y=nmds_Xt[:,1], hue=colors_samples, palette="tab10", style=shapes_samples)
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0)
plt.show()

# %% [markdown]
# # Random Forest

# %%
import seaborn as sns

# %%
newdf

# %%
y = newdf["macro_sample_ids"]
X = newdf[features]

# %%
from sklearn.model_selection import train_test_split

# %%
SEED = 42
X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    test_size=0.2, 
                                                    random_state=SEED)

# %%
from sklearn.ensemble import RandomForestClassifier

rfc = RandomForestClassifier(n_estimators=3, 
                             max_depth=2,
                             random_state=SEED)

# %%
# Fit RandomForestClassifier
rfc.fit(X_train, y_train)
# Predict the test set labels
y_pred = rfc.predict(X_test)

# %%
from sklearn.metrics import classification_report, confusion_matrix

cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt='d').set_title('Confusion matrix')

print(classification_report(y_test,y_pred))

# %%
# Organizing feature names and importances in a DataFrame
features_df = pd.DataFrame({'features': rfc.feature_names_in_, 'importances': rfc.feature_importances_ })

# Sorting data from highest to lowest
features_df_sorted = features_df.sort_values(by='importances', ascending=False)

# Barplot of the result without borders and axis lines
g = sns.barplot(data=features_df_sorted[:10], x='importances', y ='features', palette="rocket")
sns.despine(bottom = True, left = True)
g.set_title('Feature importances')
g.set(xlabel=None)
g.set(ylabel=None)
g.set(xticks=[])
for value in g.containers:
    g.bar_label(value, padding=2)

# %% [markdown]
# #### Let's generate a new model with more trees to see how it affects the results. Let's create the rfc_ forest with 900 trees, 8 levels and the same seed. Will the results improve?

# %%
rfc_ = RandomForestClassifier(n_estimators=900, 
                             max_depth=7,
                             random_state=SEED)
rfc_.fit(X_train, y_train)
y_pred = rfc_.predict(X_test)

# %%
cm_ = confusion_matrix(y_test, y_pred)
sns.heatmap(cm_, annot=True, fmt='d').set_title('Confusion matrix for 900 trees with 8 levels')

print(classification_report(y_test,y_pred))
